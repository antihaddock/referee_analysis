# %%
import pandas as pd

# %%
df = pd.read_excel('/home/antihaddock/Repos/ref_analysis/data/Disciplinary/2022 Yellow Card Register MASTER.xlsx')

# %%
df
# Out:
#       ROUND COMPETITION GRADE       DATE  \
# 0         6        NPLM   Res 2022-04-10
# 1        10        NPLM   Res 2022-05-15
# 2        11        NPLM   1st 2022-06-01
# 3        13        NPLM   1st 2022-06-05
# 4        15        NPLM   U16 2022-06-19
# ...     ...         ...   ...        ...
# 2965     PF         NL1   U18 2022-09-11
# 2966     PF         NL1   U18 2022-09-11
# 2967  MinSF         NL1   U14 2022-10-05
# 2968  MinSF         NL1   U14 2022-10-05
# 2969     PF         NL1   U18 2022-09-11
#
#                                           VENUE FIRST NAME    SURNAME  \
# 0                                    Magic Park  Mackenzie  Alexander
# 1                           Darling Street Oval  Mackenzie  Alexander
# 2                                Adamstown Oval  Mackenzie  Alexander
# 3                          Jack McLaughlan Oval  Mackenzie  Alexander
# 4                              Taree Zone Field      Harry  Armstrong
# ...
